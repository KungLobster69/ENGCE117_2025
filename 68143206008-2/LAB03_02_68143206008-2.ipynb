# %%
# names = ["alice", "bob", "charlie"]
raw_names = ["  somchai ", "alice", " BOB", "c"]
names_upper = [name.lower().strip() for name in raw_names]
print(names_upper)  

filtered = list(filter(lambda x: len(x) > 2, names_upper))
print(filtered)

result = [name.strip().lower() for name in raw_names if len(name.strip()) > 2]
print(result)
# Out:
# ['somchai', 'alice', 'bob', 'c']
# ['somchai', 'alice', 'bob']
# ['somchai', 'alice', 'bob']
