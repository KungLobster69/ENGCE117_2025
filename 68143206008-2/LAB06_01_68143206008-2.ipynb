# %%
class Spy:
    name = "James Bond"
    _agency = "MI6"
    __code = "007"

bond = Spy()

print(bond.name)
# print(bond.__code)
print(bond._agency)
print(bond._Spy__code)
# Out:
# James Bond
# MI6
# 007
