# %%
# visitors = ['user1', 'user2', 'user1', 'user3', 'user2']
# unique_data = set(visitors)
# print(unique_data)

visitors = ['user1', 'user2', 'user1', 'user3', 'user2']

unique_visitors = set(visitors)

count = len(unique_visitors)

print(f"Unique Count: {count}")
# Out:
# Unique Count: 3

# %%
group_A = {'Reading', 'Coding', 'Gaming'}
group_B = {'Coding', 'Traveling', 'Gaming'}

print(group_A & group_B)
# Out:
# {'Coding', 'Gaming'}

# %%
group_A = {'Reading', 'Coding', 'Gaming'}
group_B = {'Coding', 'Traveling', 'Gaming'}

print(group_A - group_B)
print(group_A ^ group_B)
# Out:
# {'Reading'}
# {'Traveling', 'Reading'}
