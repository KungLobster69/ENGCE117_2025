# %%
scores = [80, 55, 90, 75, 60]

first_two = scores[:2]
last_one = scores[-1:]

print(first_two, last_one)
# Out:
# [80, 55] [60]

# %%
ids = [101, 102, 103, 104, 105, 106]

reversed_ids = ids[::-1]
result = reversed_ids[0:5:2]

print(result)
# Out:
# [106, 104, 102]

# %%
data = [10, 20, 99, 99, 99, 60, 70]

data[2:5] = [0]

print(data)
# Out:
# [10, 20, 0, 60, 70]
