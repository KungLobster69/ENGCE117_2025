# %%
class Robot:
    """R1"""
    pass
r1 = Robot()
print(r1)
# Out:
# <__main__.Robot object at 0x000002B1FED852B0>

# %%
r1.name = "Commander"
r1.battery = 100

print(f"Robot Name: {r1.name}, Battery: {r1.battery}%")
# Out:
# Robot Name: Commander, Battery: 100%

# %%
r2 = Robot()
r2.name = r1.name
r2.battery = r1.battery

print("Is r1 the same as r2?", r1 is r2)

print("Address r1:", id(r1))
print("Address r2:", id(r2))
# Out:
# Is r1 the same as r2? False
# Address r1: 2963508056752
# Address r2: 2963514294992
