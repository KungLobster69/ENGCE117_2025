# %%
with open('note.txt', 'w', encoding='utf-8') as f:
    f.write("Nickname: NutlnwZa007")
print("Level 1 Complete: Created note.txt with nickname.")
# Out:
# Level 1 Complete: Created note.txt with nickname.

# %%
favorite_food = input("Enter your favorite food: ")
with open('note.txt', 'a', encoding='utf-8') as f:
    f.write("\nFavorite Food: " + favorite_food)

print("Level 2 Complete: Appended favorite food to note.txt.")
# Out:
# Level 2 Complete: Appended favorite food to note.txt.

# %%
with open('note.txt', 'r', encoding='utf-8') as f:
    content = f.read()

print("\n--- Content of note.txt ---")
print(content)
print("--------------------------")
print("Level 3 Complete: Read and displayed file content.")
# Out:
# --- Content of note.txt ---
# Nickname: NutlnwZa007
# Favorite Food:
# --------------------------
# Level 3 Complete: Read and displayed file content.
