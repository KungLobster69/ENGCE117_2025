# %%
raw_names = [" somchai ", "alice", " BOB", "c"]
cleaned_names = list(map(lambda name: name.strip().lower(), raw_names))
final_output = list(filter(lambda name: len(name) > 1, cleaned_names))

print(f"Expected Output: {final_output}")
# Out:
# Expected Output: ['somchai', 'alice', 'bob']
