# %%
from abc import ABC, abstractmethod

class IoTDevice(ABC):

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass


class SmartLight(IoTDevice):

    def turn_on(self):
        print("🌝ไฟเปิด")

    def turn_off(self):
        print("🌑ไฟปิด")
       


light = SmartLight()
light.turn_on()
light.turn_off()
# Out:
# 🌝ไฟเปิด
# 🌑ไฟปิด

# %%
from abc import ABC, abstractmethod

class IoTDevice(ABC):

    @abstractmethod
    def  methodturnon(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass


class SmartSpeaker(IoTDevice):

    def  methodturnon(self):
        print("🔊 ลำโพงเปิด")


try:
    speaker = SmartSpeaker()
except TypeError:
    print("❌Error: Can't instantiate abstract class SmartSpeakerwith abstract method turn_off")
# Out:
# ❌Error: Can't instantiate abstract class SmartSpeakerwith abstract method turn_off

# %%
from abc import ABC, abstractmethod

class IoTDevice(ABC):

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass


class SmartLight(IoTDevice):

    def turn_on(self):
        print("💡 ไฟเปิด")

    def turn_off(self):
        print("🌑 ไฟปิด")


def test_device(device):
    if isinstance(device, IoTDevice):
        print(f"Testing {device.__class__.__name__}...")
        device.turn_on()
        device.turn_off()
    else:
        print("⚠️ ไม่ใช่อุปกรณ์ IoT ที่รองรับ")


# ทดสอบ
test_device(SmartLight())
# Out:
# Testing SmartLight...
# 💡 ไฟเปิด
# 🌑 ไฟปิด
