# %%
names = ["alice","bob","charlie"]
names = [n.upper() for n in names]
print(names)
# Out:
# ['ALICE', 'BOB', 'CHARLIE']

# %%
prices = [100, 250, 80, 500, 120]
evens = [p * 1.07 for p in prices if p > 200]
print(evens)
# Out:
# [267.5, 535.0]

# %%
name_len = {'USD': 35, 'EUR': 38, 'JPY': 0.25}
Dict ={las: num for num,las in name_len.items() if las>1}
print(Dict)
# Out:
# {35: 'USD', 38: 'EUR'}
