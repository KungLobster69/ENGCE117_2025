# %%
class spy:
     def __init__ (self):
        self.name = "jamebond"
        self._agency = "MI6"
        self.__code = "007" 
bond = spy()
           
print(bond.name) #ต้องได้ James Bond
#print(bond.__code)   #ต้องได้ Error!
print(bond._agency)# ต้องได้ MI6
print(bond._spy__code) #ต้องได้ 007
# Out:
# jamebond
# MI6
# 007
