# %%
class Character:
    def __init__(self, name, hp, power):
        self.name = name
        self.hp = hp
        self.power = power
    def take_damage(self, amount):
        self.hp -= amount
        print(f"{self.name} takes {amount} damage!")
    def is_alive(self):
        return self.hp > 0

# %%
class Mage(Character):
    def __init__(self, name, hp, power, mana):
        super().__init__(name, hp, power)
        self.mana = mana

    def attack(self):
        if self.mana > 0:
            self.mana -= 10
            print(f"{self.name} attacks with magic power {self.power}!")

# %%
class Character:
    def __init__(self, name, hp):
        self.name = name
        self.hp = hp

    def is_alive(self):
        return self.hp > 0

    def take_damage(self, dmg):
        self.hp -= dmg
        if self.hp < 0:
            self.hp = 0

class Warrior(Character):
    def attack(self, target):
        print(f"{self.name} attacks {target.name}!")
        target.take_damage(10)
        print(f"> {target.name} took 10 dmg. (HP left: {target.hp})")

class Mage(Character):
    def cast_fireball(self, target):
        print(f"{self.name} casts Fireball! 🔥")
        target.take_damage(20)
        print(f"> {target.name} took 20 dmg. (HP left: {target.hp})")

# สร้างตัวละคร
arthur = Warrior("Arthur", 100)
loki = Mage("Loki", 150)

# เริ่มการต่อสู้
print("--- BATTLE START ---")
while arthur.is_alive() and loki.is_alive():
    arthur.attack(loki)
    if not loki.is_alive():
        break
    loki.cast_fireball(arthur)

# ประกาศผู้ชนะ
winner = arthur if arthur.is_alive() else loki
print(f"🏆 Winner: {winner.name}")
# Out:
# --- BATTLE START ---
# Arthur attacks Loki!
# > Loki took 10 dmg. (HP left: 140)
# Loki casts Fireball! 🔥
# > Arthur took 20 dmg. (HP left: 80)
# Arthur attacks Loki!
# > Loki took 10 dmg. (HP left: 130)
# Loki casts Fireball! 🔥
# > Arthur took 20 dmg. (HP left: 60)
# Arthur attacks Loki!
# > Loki took 10 dmg. (HP left: 120)
# Loki casts Fireball! 🔥
# > Arthur took 20 dmg. (HP left: 40)
# Arthur attacks Loki!
# > Loki took 10 dmg. (HP left: 110)
# Loki casts Fireball! 🔥
# > Arthur took 20 dmg. (HP left: 20)
# Arthur attacks Loki!
# > Loki took 10 dmg. (HP left: 100)
# Loki casts Fireball! 🔥
# > Arthur took 20 dmg. (HP left: 0)
# 🏆 Winner: Loki
