# %%
class WiFi:
    def connect(self):
        print("📡 Connected to WiFi")

class Bluetooth:
    def connect(self):
        print("🔵 Paired with Bluetooth")

w = WiFi()
b = Bluetooth()

w.connect()
b.connect()
# Out:
# 📡 Connected to WiFi
# 🔵 Paired with Bluetooth

# %%
class WiFi:
    def connect(self):
        print("📡")
        print("Connected to WiFi network")

class Bluetooth:
    def connect(self):
        print("🔵")
        print("Paired with Bluetooth device")

def initialize_system(device):
    print("System initializing")
    device.connect()

initialize_system(WiFi())
initialize_system(Bluetooth())
# Out:
# System initializing
# 📡
# Connected to WiFi network
# System initializing
# 🔵
# Paired with Bluetooth device

# %%
def  initialize_safe(device):
     try:
          print("System initializing .")
     except: raise AttributeError ("❌Error: Object 'สายแลนปลอม' ไม่มีฟงก์ชัน connect")
     fake = "สายแลนปลอม"
initialize_safe(WiFi)
initialize_safe(fake)
# Out:
# System initializing .
# System initializing .
