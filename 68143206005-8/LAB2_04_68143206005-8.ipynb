# %%
A =  ['user1','user2','user1','user3','user2']
B = set(A)
print( B )
# Out:
# {'user2', 'user1', 'user3'}

# %%
A = {'Reading','Coding','Gaming'}
B = {'Coding','Traveling','Gaming'}
print( A & B)
# Out:
# {'Coding', 'Gaming'}

# %%
A =  {'Reading','Coding','Gaming'}
B = {'Coding','Traveling','Gaming'}
print( A - B) 
print( A ^ B)
# Out:
# {'Reading'}
# {'Traveling', 'Reading'}
