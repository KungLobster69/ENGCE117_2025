# %%
class Robot:
    pass

r1 = Robot()
r2 = Robot()


r1 = Robot()
r1.name = "Commander"
r1.battery = 100


r2 = Robot()
r2.name = r1.name
r2.battery = r1.battery

print(f"{r1 == r2}")
print(f"{r1 == r2}")
# Out:
# False
# False

# %%
class Robot:
    pass

r1 = Robot()
r2 = Robot()

r1.name = "Tar"   
r1.battery = 100

r2.name ="papa"
r2.battery = 99.99

print(f"Robot Name: {r1.name}, Battery: {r1.battery}%")

print(f"Robot Name: {r2.name}, Battery: {r2.battery}%")
# Out:
# Robot Name: Tar, Battery: 100%
# Robot Name: papa, Battery: 99.99%

# %%
class Robot :
    " "
    pass

r1 = Robot()
print(r2)
