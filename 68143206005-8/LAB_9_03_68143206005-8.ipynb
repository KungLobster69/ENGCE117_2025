# %%
@add_brackets
@to_upper
def greet():
    return "hello  PYTHON"

print(greet())
# Out:
# [HELLO  PYTHON]

# %%
def add_brackets(func):
    def wrapper():
        result = func()
        return f"[{result}]"
    return wrapper

# %%
def to_upper(func):
    def wrapper():
        result = func()
        return result.upper()
    return wrapper
