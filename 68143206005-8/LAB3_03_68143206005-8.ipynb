# %%
try:
    with open(r'C:\Users\Public\note.txt', 'x', encoding='utf-8') as f:
        f.write("")
    print("Success")
except FileExistsError:
    print("File already exists")

with open("note.txt", "x") as file:
    file.write("Nickname: Pookie")
# Out:
# File already exists
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 except FileExistsError:
#       6     print("File already exists")
# ----> 8 with open("note.txt", "w") as file:
#       9     file.write("Nickname: Pookie")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'note.txt'

# %%
text = str(input())
with open('note.txt', 'a', encoding='utf-8') as f:
    f.write(f"\n{text}")

# %%
with open('note.txt', 'r', encoding='utf-8') as f:
    content = f.read()
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open('note.txt', 'r', encoding='utf-8') as f:
#       2     content = f.read()
#       3 print(content)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'note.txt'
