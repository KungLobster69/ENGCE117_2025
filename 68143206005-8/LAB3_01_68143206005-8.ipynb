# %%
def super_sum(*nums):
    return sum(nums)
print(super_sum(4, 6, 8, 10, 12))         
print(super_sum( 20, 40, 60, 80)) 
print(super_sum())
# Out:
# 40
# 200
# 0

# %%
def calculate_area(mode,args):
    if mode == "add":
        return sum(args)
    elif mode == "mult":
        result = 1
        for num in args:
            result *= num
        return result
   

print(flexi_calc("add", 2, 4, 6))    
print(flexi_calc("mult", 2, 4, 6))
# Out:
# 12
# 48

# %%
def stat_calc(mode, *args):
    if  args == None:
        return 0
    if mode == "avg":
        return sum(args) / len(args)
    elif mode == "max":
        return max(args)
   
    

print(stat_calc("avg", 10, 20, 30)) 
print(stat_calc("avg",0))
print(stat_calc("max",1,2,3))
# Out:
# 20.0
# 0.0
# 3
