# %%
def  render_screen(shape_list):
    for item in shape_list:
        item.draw()
    
    class Triangle:
        def draw(self):
            print("🔺")


    render_screen([Circle(), Square(), Circle(), Square()])

# %%
class Circle:
    def draw(self):
        print("🔴")

class Square:
    def draw(self):
        print("🟦")

shapes = [Circle(), Square(), Circle(), Square()]

for item in shapes:
    item.draw()
# Out:
# 🔴
# 🟦
# 🔴
# 🟦

# %%
class Circle:
    def make_draw(self):
              print("🔴")
class Square:
    def make_draw(self):
        print("🟦 ")
c = Circle()
s = Square()

c.make_draw()
s.make_draw()
# Out:
# 🔴
# 🟦
