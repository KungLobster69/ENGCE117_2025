# %%
class RPGCharacter:
    def __init__(self, name, hp, mp):
        self.name = name
        self.hp = hp
        self.mp = mp
    def __str__(self):
        return f"{self.name} (HP: {self.hp}, MP: {self.mp})"
    def __add__(self, other):
        if isinstance(other, RPGCharacter):
            new_name = self.name + other.name
            new_hp = self.hp + other.hp
            new_mp = self.mp + other.mp
            return RPGCharacter(new_name, new_hp, new_mp)
        elif isinstance(other, int):
            new_hp = self.hp + other
            return RPGCharacter(self.name, new_hp, self.mp)
        else:
            return NotImplemented
hero1 = RPGCharacter("Warrior", 100, 20)
hero2 = RPGCharacter("Mage", 50, 80)
print(f"Hero 1: {hero1}")  
print(f"Hero 2: {hero2}")
fusion_hero = hero1 + hero2 
print(f"Fusion: {fusion_hero}")
healed_hero = hero1 + 50 
print(f"Healed: HP: {healed_hero}")
# Out:
# Hero 1: Warrior (HP: 100, MP: 20)
# Hero 2: Mage (HP: 50, MP: 80)
# Fusion: WarriorMage (HP: 150, MP: 100)
# Healed: HP: Warrior (HP: 150, MP: 20)
