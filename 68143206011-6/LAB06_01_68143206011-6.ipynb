# %%
class Spy:
    def __init__(self):
        self.name = "Suthep Po-ngam"
        self._agency = "Uzi"
        self.__code = "Pae Uzi"
bond = Spy()
print(f"bond.Name {bond.name}")      
#print(f"bond.code{bond.__code}")จะขึ้นError!
print(f"bond.Agency {bond._agency}")
print(f"bond.Hacked Code {bond._Spy__code}")
# Out:
# bond.Name Suthep Po-ngam
# bond.Agency Uzi
# bond.Hacked Code Pae Uzi
