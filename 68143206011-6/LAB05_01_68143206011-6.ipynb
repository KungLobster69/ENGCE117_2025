# %%
class Robot :
    pass
r1 = Robot()
print(r1)
# Out:
# <__main__.Robot object at 0x000002208699A7B0>

# %%
r1.name = "Commander"
r1.battery = 100
print(f"Robot Name: {r1.name}, Battery: {r1.battery}%")
# Out:
# Robot Name: Commander, Battery: 100%

# %%
r2 = Robot()
r2.name = "Commander"
r2.battery = 100
is_same = r1 is r2
print(f"Is r1 the same as r2? {is_same}")
print(f"Address r1: {id(r1)}")
print(f"Address r2: {id(r2)}")
# Out:
# Is r1 the same as r2? False
# Address r1: 2338720425904
# Address r2: 2338721933856
