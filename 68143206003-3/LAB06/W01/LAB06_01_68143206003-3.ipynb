# %%
class Spy :
    def __init__(self):
        self.name = "James Bond"
        self._agency = "MI6"   
        self.__code = "007"
bond = Spy()

# บรรทัดนี้เอาไว้ทดสอบว่าแสดงอะไรบ้าง
#print(dir(bond))
print(f"name : {bond.name}")
# บรรทัดนี้จะ Error เพราะ __code เป็น Private 
#print(bond.__code)
print(f"Agency : {bond._agency}")
print(f"Code Number : {bond._Spy__code}")
# Out:
# name : James Bond
# Agency : MI6
# Code Number : 007
