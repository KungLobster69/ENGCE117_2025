# %%
names = ["alice","bob","charlie"]
names = [n.upper() for n in names]
print(names)
# Out:
# ['ALICE', 'BOB', 'CHARLIE']

# %%
prices = [100, 250, 80, 500, 120]
prices = [x*1.07 for x in prices if x>200]
print(prices)
# Out:
# [267.5, 535.0]

# %%
currencies = {'USD': 35,'EUR': 38,'JPY': 0.25}
b = {num: name for name, num in currencies.items() if num>1}
print(b)
# Out:
# {35: 'USD', 38: 'EUR'}
