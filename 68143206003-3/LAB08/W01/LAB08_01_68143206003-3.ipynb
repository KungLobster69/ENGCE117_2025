# %%
class Circle:
    def draw(self):
        print("🔴 วาดวงกลม")
class Square:
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")
c = Circle()
s = Square()

c.draw()
s.draw()
# Out:
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
class Circle:
    def draw(self):
        print("🔴 วาดวงกลม")
class Square:
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")
shapes = [Circle(), Square(), Circle(), Square()]

print("--- เริ่มการวาดแบบ Loop ---")

for item in shapes:
    item.draw()
# Out:
# --- เริ่มการวาดแบบ Loop ---
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
class Circle:
    def draw(self):
        print("🔴 วาดวงกลม")
class Square:
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")
class Triangle:
    def draw(self):
        print("🔺 วาดสามเหลี่ยม")
def render_screen(shape_list):
    print(f"--- Rendering {len(shape_list)} shapes ---")
    for shape in shape_list:
        shape.draw()
shapes = [Circle(), Triangle(), Square()]

render_screen(shapes)
# Out:
# --- Rendering 3 shapes ---
# 🔴 วาดวงกลม
# 🔺 วาดสามเหลี่ยม
# 🟦 วาดสี่เหลี่ยม
