# %%
class Robot :
    """ต้นแบบ"""
    pass

r1 = Robot()
print(r1)

# %%
class Robot :
    pass

r1 = Robot()

r1.name = "Commander"
r1.battery = 100

print(f"Robot Name: {r1.name}, Battery: {r1.battery}%")
# Out:
# Robot Name: Commander, Battery: 100%

# %%
class Robot :
    pass

r1 = Robot()

r1.name = "Commander"
r1.battery = 100
class Robot :
    pass

r2 = Robot()

r2.name = "Shoger"
r2.battery = 100

print(f"Is r1 the same as r2 = {r1 == r2}") # == ค่าเท่ากันไหม
print(f"Is r1 the object as r2 = {r1 is r2}") # is เป็น object เดียวกันไหม
print(f"Address r1: {id(r1)}")
print(f"Address r2: {id(r2)}")
# Out:
# Is r1 the same as r2 = False
# Is r1 the object as r2 = False
# Address r1: 2886305685792
# Address r2: 2886305686800
