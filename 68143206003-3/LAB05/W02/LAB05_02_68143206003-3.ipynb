# %%
class Robot:
    def __init__(self,name,model):
        self.name = name
        self.model = model
    
    def show_info(self):
        print(f"Robot: {self.name} ({self.model})")             
        
r1 = Robot("R-01", "Explorer")
r1.show_info()
# Out:
# Robot: R-01 (Explorer)

# %%
class Robot:
    def __init__(self,name,model,battery=100):
        self.name = name
        self.model = model
        self.battery = battery
        
    def show_battery(self):
        print(f"{self.name} Battery: {self.battery}%")
        
r2 = Robot("R-02", "Guardian")
r2.show_battery()
# Out:
# R-02 Battery: 100%

# %%
class Robot:
    def __init__(self, name, model, battery=100):
        self.name = name
        self.model = model
        self.battery = battery

        # Level 3: ตรวจสอบแบตเตอรี่ต่ำ
        if self.battery < 20:
            print(f"Warning: {self.name} has Low Battery!")

    def show_info(self):
        print(f"Robot: {self.name} ({self.model})")

    def show_battery(self):
        print(f"{self.name} Battery: {self.battery}%")
r3 = Robot("R-03", "Scout", 10)
