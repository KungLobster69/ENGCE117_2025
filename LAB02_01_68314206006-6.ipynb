# %%
scores = [80, 55, 90, 75, 60]
f = scores [:2]
l = scores [4:]
print(f,l)
# Out:
# [80, 55] [60]

# %%
ids = [101, 102, 103, 104, 105, 106]
re_ids = ids [::-1]
print(re_ids[::2])
# Out:
# [106, 104, 102]

# %%
import copy
data = [10, 20, 99, 99, 99, 60, 70]
cdata = copy.deepcopy(data)
cdata[2:5] = [0]
print(cdata)
# Out:
# [10, 20, 0, 60, 70]
