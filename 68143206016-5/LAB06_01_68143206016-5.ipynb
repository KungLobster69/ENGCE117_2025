# %%
class spy:
    def __init__(bond):
        bond.name = "James Bond"
        bond._agency = "M16"
        bond.spy__code = "007"

        pass

bond = spy()

print(bond.name)
print(bond._agency)

try:
    print(bond.__code)
except  AttributeError:
    print("Error")
print(bond.spy__code)
# Out:
# James Bond
# M16
# Error
# 007
