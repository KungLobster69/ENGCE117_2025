# %%
def super_sum(*nums):
    return sum(nums)

super_sum(10,5,6,3,1)
# Out:
# 25

# %%
def flexi_calc(mode,*args):
 if mode == "add":
        return sum(args)
 elif mode == "mult":
        result = 1 
        for number in args:
            result *= number 
        return result       
 else :
    print("กรอกให้ถูกด้วยจ้า")

flexi_calc("mult",10,20,30)
def stat_calc(mode,*args):
    if len(args) == 0:
        return 0
    elif mode == "avg":
      return sum(args) / len(args)
    elif mode == "max":
      return max(args)
    else :
        print("กรอกให้ถูกด้วยจ้า")


stat_calc("avg")
# Out:
# 0

# %%
def stat_calc(mode,*args):
    if len(args) == 0:
        return 0
    elif mode == "avg":
      return sum(args) / len(args)
    elif mode == "max":
      return max(args)
    else :
        print("กรอกให้ถูกด้วยจ้า")


stat_calc("avg")
# Out:
# 0
