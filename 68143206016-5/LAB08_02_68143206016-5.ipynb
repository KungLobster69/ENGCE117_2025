# %%
class WiFi:
    def connect(self):
        print ("📡 Connected to WiFi network")

class Bluetooth:
    def connect(self):
        print ("🔵 Paired with Bluetooth device")

Object = [WiFi(),Bluetooth()]
for item in Object:
    item.connect()
# Out:
# 📡 Connected to WiFi network
# 🔵 Paired with Bluetooth device

# %%
def initialize_system(device):
    for object in device:
        object.connect()

Object = [WiFi(),Bluetooth()]
for item in Object:
    print ("System initializing...")
    item.connect()
# Out:
# System initializing...
# 📡 Connected to WiFi network
# System initializing...
# 🔵 Paired with Bluetooth device

# %%
def initialize_system(device):
    try:
        print ("System initializing...")
        device.connect()
    except AttributeError:
        print (f"❌ Error {device} : เชื่อมต่อไม่ได้ ")

initialize_system(Object)
# Out:
# System initializing...
# ❌ Error [<__main__.WiFi object at 0x000001454D425E50>, <__main__.Bluetooth object at 0x000001454D4265D0>] : เชื่อมต่อไม่ได้
