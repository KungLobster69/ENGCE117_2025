# %%
#Lavel 1
names = ['alice','bob','charlie']
up_name = [name.upper() for name in names]
print(up_name)
# Out:
# ['ALICE', 'BOB', 'CHARLIE']

# %%
#Lavel 2
prices = [100, 250, 80, 500, 120]

p = [n+n*(7/100) for n in prices if n > 200]

print(p)
# Out:
# [267.5, 535.0]

# %%
#Lavel 3
currencies = {'USD':35, 'EUR':38, 'JPY':0.25}

inveted = {v:k for k, v in currencies.items() if v > 1}

print(inveted)
# Out:
# {35: 'USD', 38: 'EUR'}
