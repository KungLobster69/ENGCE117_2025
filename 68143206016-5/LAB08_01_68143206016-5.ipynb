# %%
class Circle:
    def draw(self):
        print("🔴 วาดวงกลม")

class Square:
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")

object = [Circle(), Square()]
for shape in object:
    shape.draw()
# Out:
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
class Circle:
    def draw(self):
        print("🔴 วาดวงกลม")

class Square:
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")

shapes = [Circle(), Square(), Circle(), Square()]
for item in shapes:
    item.draw()
# Out:
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
class Triangle:
    def draw(self):
        print("🔺 วาดสามเหลี่ยม")

def render_screen(shape_list):
    for shape in shape_list:
        shape.draw()

shapes = [Circle(), Square(), Triangle()]
for item in shapes:
    item.draw()
# Out:
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม
# 🔺 วาดสามเหลี่ยม
