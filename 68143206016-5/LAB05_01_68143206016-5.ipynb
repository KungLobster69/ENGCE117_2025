# %%
class Robot:
    pass
r1 = Robot()
r2 = Robot()
print(r1)
print(r2)

# %%
r1.Name = "Commander"
r1.Battery = 100

print(f"Robot Name : {r1.Name}, Battery : {r1.Battery}%")
# Out:
# Robot Name : Commander, Battery : 100%

# %%
Is_same = (r1 is r2)

print(f"Is r1 the same as r2 ?",{Is_same})
print(f"FalseAddress r1: ",id(r1))
print(f"Address r1: ",id(r2))
# Out:
# Is r1 the same as r2 ? {False}
# FalseAddress r1:  2592778266208
# Address r1:  2592784291536
