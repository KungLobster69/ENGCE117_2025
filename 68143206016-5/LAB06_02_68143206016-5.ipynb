# %%
class Square:
    def __init__(self, side):
        self.__side = side

    @property
    def side(self):
        return self.__side

    @side.setter
    def side(self, value):
        if value > 0:
            self.__side = value
        else :
            print("Error ต้องป้อนค่าที่มากกว่า 0")

    @property
    def area(self):
        return self.__side * self.__side
    
s = Square(4)
print(f"Side: {s.side}, Area: {s.area}")
s.side = 5
print(f"New Area: {s.area}")
s.side = -10
s.area = 100
# Out:
# Side: 4, Area: 16
# New Area: 25
# Error ต้องป้อนค่าที่มากกว่า 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 25
#      23 print(f"New Area: {s.area}")
#      24 s.side = -10
# ---> 25 s.area = 100
#
# AttributeError: property 'area' of 'Square' object has no setter
