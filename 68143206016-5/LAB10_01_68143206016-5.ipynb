# %%
import tkinter as tk

root = tk.Tk("My First App")
root.geometry("400x300")
tk.Label(root, text = "Hello GUI").pack()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 root.geometry("400x300")
#       5 tk.Label(root, text = "Hello GUI").pack()
# ----> 6 root.mainloop()
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py:1599, in Misc.mainloop(self, n)
#    1597 def mainloop(self, n=0):
#    1598     """Call the mainloop of Tk."""
# -> 1599     self.tk.mainloop(n)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
