# %%
#Lavel 1
student = ('Somchai', 'Engineering', 3.75)
name,dept,gpa = student

print(f'Output: Name:{name}, Dept:{dept}, GPA:{gpa}')
# Out:
# Output: Name:Somchai, Dept:Engineering, GPA:3.75

# %%
#Lavel 2
numbers = [1, 2, 3, 4, 5]
def get_stuts(numbers):
    min_val = 1
    max_val = 5
    return min_val, max_val
min, max = get_stuts(numbers)

print(f'Min:{min} Max:{max}')
# Out:
# Min:1 Max:5

# %%
#Lavel 3
scores = [10, 20 ,30, 40, 50, 60]
head, *middle, end = scores
print(f'Low: {head}')
print(f'Other: {middle}')
print(f'High: {end}')
# Out:
# Low: 10
# Other: [20, 30, 40, 50]
# High: 60
