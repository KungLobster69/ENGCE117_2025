# %%
names = ["alice","bob","charlie"]
uppername = [ name.upper() for name in names]
print(uppername)
# Out:
# ['ALICE', 'BOB', 'CHARLIE']

# %%
price = [100,250,80,500,120]
highprice200 = [((x*0.07)+x) for x in price if x > 200]
print(highprice200)
# Out:
# [267.5, 535.0]

# %%
currencies = {'USD': 35,'EUR':38 ,'JPY':0.25}
inver = { v: k for k,v in currencies.items() if v > 1 }
print(inver)
# Out:
# {35: 'USD', 38: 'EUR'}
