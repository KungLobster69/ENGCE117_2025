# %%
class RobotPart():
    category = "Mechanical"
    def __init__(self,name):
        self.name = name
x = RobotPart("Motor")  
print(f"Part:{x.name},Type:{x.category}")
# Out:
# Part:Motor,Type:Mechanical

# %%
class RobotPart():
    category = "Mechanical"
    total_count = 0
    def __init__(self,name):
        self.name = name
        RobotPart.total_count += 1
x1 = RobotPart("Motor")
x2 = RobotPart("Motor")  
print(f"Part:{x1.name},Type:{x1.category}") 
print(f"Total parts in system:{RobotPart.total_count}")
# Out:
# Part:Motor,Type:Mechanical
# Total parts in system:2

# %%
class RobotPart():
    category = "Mechanical"
    total_count = 0
    def __init__(self,name):
        self.name = name
        RobotPart.total_count += 1
x1 = RobotPart("Motor")
x2 = RobotPart("Motor")
x3 = RobotPart("Motor")  
print(f"Part:{x1.name},Type:{x1.category}") 
print(f"Total parts in system:{RobotPart.total_count}")
x3.total_count is RobotPart.total_count
# Out:
# Part:Motor,Type:Mechanical
# Total parts in system:3
# True
