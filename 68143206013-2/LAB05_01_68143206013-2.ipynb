# %%
class robot():
    pass
r1 = robot()
print(r1)

# %%
class robot():
    pass
r1 = robot()
r1.name = "Commander"
r1.battery = 100
print(f"Robot Name:{r1.name},Battery:{r1.battery}%")
# Out:
# Robot Name:Commander,Battery:100%

# %%
class robot():
    pass
r1 = robot()
r2 = robot()
r1 is r2
# Out:
# False
