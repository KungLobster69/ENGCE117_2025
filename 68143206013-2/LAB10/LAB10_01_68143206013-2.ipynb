# %%
import tkinter as tk

root = tk.Tk()
tk.Label(root).pack()
root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()
tk.Label(root,text = "Hello GUI").pack()
root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()
root.title("My First App")            
root.geometry("400x300")
tk.Label(root, text="Hello GUI").pack()  
root.mainloop()
