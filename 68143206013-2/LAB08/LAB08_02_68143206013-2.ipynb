# %%
class Wifi():
    def connect(self):
        print("📡 Connected to WiFi...")
class Bluetooth():
    def connect(self):
        print("🔵 Paired with Bluetooth...")
w = Wifi()
b = Bluetooth()
w.connect()
b.connect()
# Out:
# 📡 Connected to WiFi...
# 🔵 Paired with Bluetooth...

# %%
class Wifi():
    def connect(self):
        print("📡 Connected to WiFi...")
class Bluetooth():
    def connect(self):
        print("🔵 Paired with Bluetooth...")
def iniitialize_system(device):
    print("System initializing...")
    device.connect()
iniitialize_system(Wifi())
iniitialize_system(Bluetooth())
# Out:
# System initializing...
# 📡 Connected to WiFi...
# System initializing...
# 🔵 Paired with Bluetooth...

# %%
class Wifi():
    def connect(self):
        print("📡 Connected to WiFi...")
class Bluetooth():
    def connect(self):
        print("🔵 Paired with Bluetooth...")
def iniitialize_safe(device):
    try:
        print("System initializing...")
        device.connect()
    except AttributeError:
        print('ERROR สายแลนปลอม')     
iniitialize_safe(56415645645651)
# Out:
# System initializing...
# ERROR สายแลนปลอม
