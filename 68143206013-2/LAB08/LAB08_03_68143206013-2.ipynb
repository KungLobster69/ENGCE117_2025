# %%
from abc import ABC, abstractmethod
class ioTDevice(ABC):
    @abstractmethod
    def turn_on(self):
        pass
    @abstractmethod
    def turn_off(self):
        pass        
class SmartLight(ioTDevice):
    def turn_on(self):
        print("💡 ไฟเปิด")
    def turn_off(self):
        print("🌑 ไฟปิด")
light = SmartLight()
light.turn_on()
light.turn_off()
# Out:
# 💡 ไฟเปิด
# 🌑 ไฟปิด

# %%
from abc import ABC, abstractmethod
class ioTDevice(ABC):
    @abstractmethod
    def turn_on(self):
        pass
    @abstractmethod
    def turn_off(self):
        pass        
class SmartLight(ioTDevice):
    def turn_on(self):
        print("💡 ไฟเปิด")
    def turn_off(self):
        print("🌑 ไฟปิด")
class SmartSpeaker(ioTDevice):
    def turn_on(self):
        print("🔊 ลํา โพงเปิด")
                    
try:
    s = SmartSpeaker()
except TypeError:
    print("❌ Error: Can't instantiate abstract class SmartSpeaker with abstract method turn_off")
# Out:
# ❌ Error: Can't instantiate abstract class SmartSpeaker with abstract method turn_off

# %%
from abc import ABC, abstractmethod
class ioTDevice(ABC):
    @abstractmethod
    def turn_on(self):
        pass
    @abstractmethod
    def turn_off(self):
        pass        
class SmartLight(ioTDevice):
    def turn_on(self):
        print("💡 ไฟเปิด")
    def turn_off(self):
        print("🌑 ไฟปิด")

s = SmartLight()
def test_device(device):
    if isinstance(device,ioTDevice):
        print("Testing SmartLight...")
        device.turn_on()
        device.turn_off()
    else:
        print("⚠️ ไม่ใช่อุปกรณ์IoTที่รองรับ")
test_device(SmartLight())
test_device("wwadawda")
# Out:
# Testing SmartLight...
# 💡 ไฟเปิด
# 🌑 ไฟปิด
# ⚠️ ไม่ใช่อุปกรณ์IoTที่รองรับ
