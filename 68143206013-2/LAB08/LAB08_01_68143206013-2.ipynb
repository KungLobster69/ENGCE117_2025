# %%
class Circle():
    def draw(self):
        print("🔴วงกลม")
class Square():
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")
c = Circle()
s = Square()
c.draw()
s.draw()
# Out:
# 🔴วงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
class Circle():
    def draw(self):
        print("🔴วงกลม")
class Square():
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")
shapes = [Circle(),Square(),Circle(),Square()]
for i in shapes:
    i.draw()
# Out:
# 🔴วงกลม
# 🟦 วาดสี่เหลี่ยม
# 🔴วงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
class Circle():
    def draw(self):
        print("🔴วงกลม")
class Square():
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")
class Triangle():
    def draw(self):
        print("🔺 วาดสามเหลี่ยม")
shapes = [Circle(),Square(),Circle(),Square(),Triangle()]
def render_screen(shapes_list):
    for x in shapes_list:
        x.draw()   
render_screen(shapes)
# Out:
# 🔴วงกลม
# 🟦 วาดสี่เหลี่ยม
# 🔴วงกลม
# 🟦 วาดสี่เหลี่ยม
# 🔺 วาดสามเหลี่ยม
