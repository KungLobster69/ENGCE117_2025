# %%
class playlist:
    song = ['songA','songB','songC']
    def __init__(self,song):
        self.song = list(song)
    def __len__(self):
        return len(self.song)
    def __getitem__(self,index):
        if isinstance(index,slice):
            return   playlist(self.song[index])
        return self.song[index]   
p =playlist.song 
print(p[1])
# Out:
# songB

# %%
class playlist:
    song = ['songA','songB','songC']
    def __init__(self,song):
        self.song = list(song)
    def __len__(self):
        return len(self.song)
    def __getitem__(self,index):
        if isinstance(index,slice):
            return   playlist(self.song[index])
        return self.song[index]
    def __setitem__(self,index,y):
        self.song[index] = y
    def __contains__(self,song):
        return song in self.song    
p =playlist.song 
print(p[1])
p[0] = "song1111111111"  
print(p[0])
# Out:
# songB
# song1111111111

# %%
class playlist:
    song = ['songA','songB','songC','songD','songE']
    def __init__(self,song):
        self.song = list(song) 
    def __len__(self):
        return len(self.song)
    def __getitem__(self,index):
        if isinstance(index,slice):
            return   playlist(self.song[index])
        return self.song[index]
    def __setitem__(self,index,y):
        self.song[index] = y
    def __contains__(self,song):
        return song in self.song
p =playlist.song
r = p[0:2]                
print(r)
# Out:
# ['songA', 'songB']
