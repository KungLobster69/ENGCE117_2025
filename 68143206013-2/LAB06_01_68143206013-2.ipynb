# %%
class spy():
    def __init__(self,name,agency,code):
        self.name = name
        self._agency = agency
        self.__code = code
bond = spy("James Bond","MI6","007")
print(bond.name)
print(bond._agency)
print(bond._spy__code)
# Out:
# James Bond
# MI6
# 007
