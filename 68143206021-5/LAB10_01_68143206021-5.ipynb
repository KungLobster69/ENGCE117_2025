# %%
#Lavel 1
import tkinter as tk
root = tk.Tk()
root.mainloop()

# %%
#Lavel 2
root = tk.Tk()
tk.Label(root, text="Hello GUI!").pack()
root.mainloop()

# %%
#Lavel 3
root = tk.Tk()
root.title("My First App")
tk.Label(root, text="Hello GUI!").pack()
root.geometry("400x300")
root.mainloop()
