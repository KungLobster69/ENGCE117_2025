# %%
#Level 1 Base Class
class Character:
    def __init__(self, name, hp, power):
        self.name = name
        self.hp = hp
        self.power = power

    def take_damage(self, amount):
        self.hp -= amount
        print(f"> {self.name} took {amount} dmg. (HP left: {self.hp})")

    def is_alive(self):
        return self.hp > 0


#Level 2 Derived Class + super()
class Warrior(Character):
    def __init__(self, name, hp, power, defense):
        super().__init__(name, hp, power)
        self.defense = defense

    def take_damage(self, amount):
        reduced = max(amount - self.defense, 0)
        super().take_damage(reduced)


class Mage(Character):
    def __init__(self, name, hp, power, mana):
        super().__init__(name, hp, power)
        self.mana = mana

    def attack(self, target):
        if self.mana >= 10:
            print(f"{self.name} casts Fireball! 🔥")
            damage = self.power + 15
            self.mana -= 10
        else:
            print(f"{self.name} attacks with staff.")
            damage = self.power
        target.take_damage(damage)


#Level 3 Polymorphism
# สร้างตัวละคร
arthur = Warrior("Arthur", hp=100, power=20, defense=10)
loki = Mage("Loki", hp=80, power=10, mana=30)

# เริ่มการต่อสู้
print("--- BATTLE START ---")
turn = 0

while arthur.is_alive() and loki.is_alive():
    if turn % 2 == 0:
        print(f"{arthur.name} attacks {loki.name}!")
        loki.take_damage(arthur.power)
    else:
        loki.attack(arthur)
    turn += 1

# ประกาศผู้ชนะ
winner = arthur if arthur.is_alive() else loki
print(f"🏆 Winner: {winner.name}")
# Out:
# --- BATTLE START ---
# Arthur attacks Loki!
# > Loki took 20 dmg. (HP left: 60)
# Loki casts Fireball! 🔥
# > Arthur took 15 dmg. (HP left: 85)
# Arthur attacks Loki!
# > Loki took 20 dmg. (HP left: 40)
# Loki casts Fireball! 🔥
# > Arthur took 15 dmg. (HP left: 70)
# Arthur attacks Loki!
# > Loki took 20 dmg. (HP left: 20)
# Loki casts Fireball! 🔥
# > Arthur took 15 dmg. (HP left: 55)
# Arthur attacks Loki!
# > Loki took 20 dmg. (HP left: 0)
# 🏆 Winner: Arthur
