# %%
#Lavel 1
import os
cwd = os.getcwd()
print(cwd)

file = os.path.join(cwd, "data", "note.txt")
print(file)

try:
   with open("note.txt", 'w') as f:
      f.write("Nickname: Nun\n")
   print("ไปละ")
except FileExistsError:
   print('ไม่ได้เฮ้ย')
# Out:
# /home/themoon/Documents/ENGCE117
# /home/themoon/Documents/ENGCE117/data/note.txt
# ไปละ

# %%
#Lavel 2
with open('note.txt', 'a') as f:
    f.write('อาหารที่ชอบ: ')
    f.write(input("ใส่กับข้าวที่ชอบนะ:" ))
    print('Success')
# Out:
# Success

# %%
#Lavel 3
with open('note.txt', 'r') as f:
    data = f.read()
    print(data)
# Out:
# Nickname: Nun
# อาหารที่ชอบ: ไข่ทอด
