# %%
class spy():
    def __init__(self,name):
        self.name = name
        self._agency = 'M16'
        self.__code = '007'

bond = spy('James Bond')

print(bond.name)
print(bond._spy__code)
print(bond._agency)
print(bond.__code)
# Out:
# James Bond
# 007
# M16
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 12
#      10 print(bond._spy__code)
#      11 print(bond._agency)
# ---> 12 print(bond.__code)
#
# AttributeError: 'spy' object has no attribute '__code'
