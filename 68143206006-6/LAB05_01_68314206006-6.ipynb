# %%
class Robot:
    pass

# %%
r1 = Robot()
print(r1)

# %%
class Robot:
    def __init__(self,name,battery):
        self.battery = battery
        self.name = name

# %%
print(r1.name)
print(f"{r1.battery}%")
# Out:
# Commander
# 100%

# %%
r2 = Robot("Commander",100)
print(f"Is r1 the same as r2:{id(r1) == id(r2)} Address r1:{id(r1)} Address r2:{id(r2)}",)
# Out:
# Is r1 the same as r2:False Address r1:2251446677056 Address r2:2251453811440
