# %%
student = ("Somchi", "Engineering", 3.75)
name, dept, gpa = student
print(f"Name:{name} Dept:{dept} GPA:{gpa}")
# Out:
# Name:Somchi Dept:Engineering GPA:3.75

# %%
def get_stats():
    min_val = min(num)
    max_val = max(num)
    return min_val,max_val

# %%
    num = tuple(map(int, input("Enter numbers: ").split()))
    min_val, max_val = get_stats()
    print(f"Min: {min_val}  Max: {max_val}")
# Out:
# Min: 0  Max: 213456789

# %%
    scores = [10, 20, 30, 40, 50, 60]
    low, *other, high = scores
    print(f"Low:{low},High:{high},Others:{other}")
# Out:
# Low:10,High:60,Others:[20, 30, 40, 50]
