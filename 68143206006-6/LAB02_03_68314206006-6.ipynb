# %%
inventory = {'apple': 10, 'banana': 20}

# %%
def check_price():
    price = inventory.get(item_name)
    return price if price is not None else 0

# %%
item_name = input("Enter item: ")
return_price = check_price()
print(f"check {item_name}: {return_price}")
# Out:
# check durian: 0

# %%
def add_stock(item, quantity):
    inventory[item] = inventory.get(item, 0) + quantity
item, quantity = input("Enter item,quantity: ").split(",")
quantity = int(quantity)
add_stock(item, quantity)
print(inventory)
# Out:
# {'apple': 15, 'banana': 20, 'durian': 25}

# %%
branch2 = {'banana': 5,'orange': 10}
for item, qty in branch2.items():
    inventory[item] = inventory.get(item, 0) + qty
print(inventory)
# Out:
# {'apple': 15, 'banana': 25, 'durian': 25, 'orange': 10}
