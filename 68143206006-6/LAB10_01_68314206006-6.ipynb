# %%
import tkinter as tk

# %%
root = tk.Tk()
root.mainloop()

# %%
root = tk.Tk()
tk.Label(root, text="Hello GUI!").pack()
root.mainloop()

# %%
root = tk.Tk()
root.title("My First App")
tk.Label(root, text="Hello GUI!").pack()
root.geometry("400x300")
root.mainloop()
