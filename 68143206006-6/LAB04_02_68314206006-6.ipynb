# %%
def even_gen(limit):
    for i in range(limit+1):
        if i % 2 == 0:
            yield i
        else: continue

# %%
for x in even_gen(10):
    print(x)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
def intermediate()
