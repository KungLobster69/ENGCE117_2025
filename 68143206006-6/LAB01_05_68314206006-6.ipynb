# %%
names = ["alice", "bob", "charlie"]
name_up = [word.upper() for word in names]
print(f"Upper:{name_up}")
# Out:
# Upper:['ALICE', 'BOB', 'CHARLIE']

# %%
prices = [100, 250, 80, 500, 120]
add_tax = [t + t*0.07 for t in prices if t >= 200]
print(f"VAt Prices:{add_tax}")
# Out:
# VAt Prices:[267.5, 535.0]

# %%
currencies = {'USD': 35,'EUR': 38,'JPY': 0.25}
redict = {v:k for k, v in currencies.items() if v > 1}
print(redict)
# Out:
# {35: 'USD', 38: 'EUR'}
