# %%
class Robot:
    
    pass

r1 = Robot()

print(r1)

# %%
r1 = Robot()
r1.name = "Commander"
r1.battery = "Battery: 100%"
print(f"{r1.name} , {r1.battery}")
# Out:
# Commander , Battery: 100%

# %%
r1 = Robot()
r2 = Robot()

is_same_as = (r1 is r2)

print(f"Is r1 the same as r2 ? {is_same_as}")
print(f"Address r1: {id(r1)}")
print(f"Address r2: {id(r2)}")
# Out:
# Is r1 the same as r2 ? False
# Address r1: 2117862705744
# Address r2: 2117859357232
