# %%
class Spy:
    def __init__(self):
        self.name = "James Bond"
        self._agency = "MI6"
        self.__code = "007"

bond = Spy()

print(bond.name) 
print(bond._agency) 
print(bond._Spy__code)

try:
    print(bond.__code)
except AttributeError:
    print("Error")
# Out:
# James Bond
# MI6
# 007
# Error
