# %%
#Level 1
score = [80 ,55 ,90 ,75 ,60]
print(score[0:2])
print(score[4:])
#Level 2
ids = [101, 102, 103, 104, 105, 106]
reversed = (ids[::-1])
print(reversed[::2])
#Level 3
data = [10, 20, 99, 99, 99, 60, 70]
del data[2:5]
data[2:1] = [0]
print(data)
# Out:
# [80, 55]
# [60]
# [106, 104, 102]
# [10, 20, 0, 60, 70]
