# %%
##WorkShop01
class RPGCharacter:
    def __init__(self, name, hp, mp):
        self.name = name
        self.hp = hp
        self.mp = mp
    
    def __str__(self):
        return f"NAME:{self.name} HP:{self.hp} MP:{self.mp}"
    
    def __add__(self, other):
        if isinstance(other, RPGCharacter):
            new_name = self.name + other.name
            new_hp = self.hp + other.hp
            new_mp = self.mp + other.mp
            return RPGCharacter(new_name, new_hp, new_mp)
        elif isinstance(other, int):
            new_hp = self.hp + other
            return RPGCharacter(self.name, new_hp ,self.mp)
        else:
            return NotImplemented
        
hero1 = RPGCharacter("Wariorr" , 100 , 50)
hero2 = RPGCharacter("Mage" , 80 , 100)

print(f"Hero1: {hero1}")
print(f"Hero2: {hero2}")
# Out:
# Hero1: NAME:Wariorr HP:100 MP:50
# Hero2: NAME:Mage HP:80 MP:100

# %%
##WorkShop02
class RPGCharacter:
    def __init__(self, name, hp, mp):
        self.name = name
        self.hp = hp
        self.mp = mp
    
    def __str__(self):
        return f"NAME:{self.name} HP:{self.hp} MP:{self.mp}"
    
    def __add__(self, other):
        if isinstance(other, RPGCharacter):
            new_name = self.name + other.name
            new_hp = self.hp + other.hp
            new_mp = self.mp + other.mp
            return RPGCharacter(new_name, new_hp, new_mp)
        elif isinstance(other, int):
            new_hp = self.hp + other
            return RPGCharacter(self.name, new_hp ,self.mp)
        else:
            return NotImplemented
        
hero1 = RPGCharacter("ราชา" , 100 , 50)
hero2 = RPGCharacter("ตาเดียว" , 50 , 100)

print(f"Hero1: {hero1}")
print(f"Hero2: {hero2}")

archmage = hero1 + hero2
print(f"SuperClass: {archmage}")
# Out:
# Hero1: NAME:ราชา HP:100 MP:50
# Hero2: NAME:ตาเดียว HP:50 MP:100
# SuperClass: NAME:ราชาตาเดียว HP:150 MP:150

# %%
##WorkShop03
class RPGCharacter:
    def __init__(self, name, hp, mp):
        self.name = name
        self.hp = hp
        self.mp = mp
    
    def __str__(self):
        return f"NAME:{self.name} HP:{self.hp} MP:{self.mp}"
    
    def __add__(self, other):
        if isinstance(other, RPGCharacter):
            new_name = self.name + other.name
            new_hp = self.hp + other.hp
            new_mp = self.mp + other.mp
            return RPGCharacter(new_name, new_hp, new_mp)
        elif isinstance(other, int):
            new_hp = self.hp + other
            return RPGCharacter(self.name, new_hp ,self.mp)
        else:
            return NotImplemented
        
hero1 = RPGCharacter("Wariorr" , 100 , 50)
hero2 = RPGCharacter("Mage" , 80 , 100)

print(f"Hero1: {hero1}")
print(f"Hero2: {hero2}")

heal_zone = hero1 +50
print(f"HealZone: {heal_zone}")
print(f"OGHP: {hero1}")
# Out:
# Hero1: NAME:Wariorr HP:100 MP:50
# Hero2: NAME:Mage HP:80 MP:100
# HealZone: NAME:Wariorr HP:150 MP:50
# OGHP: NAME:Wariorr HP:100 MP:50
