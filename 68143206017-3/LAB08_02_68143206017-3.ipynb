# %%
class WiFi:
    def connect(self): print("📡 Connected to WiFi...")

class Bluetooth:
    def connect(self): print("🔵Paired with Bluetooth...")

def lift_off(entity):
    entity.connect()

network1 = WiFi()
network2 = Bluetooth()

connected = [WiFi(),Bluetooth()]

for c in connected:
    c.connect()
# Out:
# 📡 Connected to WiFi...
# 🔵Paired with Bluetooth...

# %%
class WiFi:
    def connect(self): print("📡 Connected to WiFi...")

class Bluetooth:
    def connect(self): print("🔵Paired with Bluetooth...")

def initialize_system(device):
    print("System initaializing...")
    device.connect()

initialize_system(WiFi())
initialize_system(Bluetooth())
# Out:
# System initaializing...
# 📡 Connected to WiFi...
# System initaializing...
# 🔵Paired with Bluetooth...

# %%
class WiFi:
    def connect(self): print("📡 Connected to WiFi...")

class Bluetooth:
    def connect(self): print("🔵Paired with Bluetooth...")


def initialize_system(device):
    print("System initaializing...")
    device.connect()

try:
    initialize_system(WiFi(0))
except:
    print("❌Error:Object'สายแลนปลอม'ไม่มีฟังก์ชัน Connect")
# Out:
# ❌Error:Object'สายแลนปลอม'ไม่มีฟังก์ชัน Connect
