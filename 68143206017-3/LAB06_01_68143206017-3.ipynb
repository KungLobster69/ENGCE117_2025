# %%
##WorkShop_01

class spy:
    def __init__(self, name):
        self.name = name
        self._agency = "MI6"
        self.__code = "007"

bound = spy("James Bond")

print(bound.name)
print(bound._agency)
##print(bound.__code) Error!
print(bound._spy__code)
# Out:
# James Bond
# MI6
# 007
