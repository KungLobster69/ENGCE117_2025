# %%
scores = [80,55,90,75,60]

# %%
last = []
new = scores[0:2]
last.append(scores[4])
print(new,last)
# Out:
# [80, 55] [60]

# %%
import copy
ids = [101,102,103,104,105,106]

# %%
ids_copy = copy.deepcopy(ids)
ids_copy.reverse()
print(ids_copy[::2])

# %%
data = [10,20,99,99,99,60,70]

# %%
data[2:5] = [0]
print(data)
