# %%
import tkinter as tk

# %%
## ระดับ 1
root = tk.Tk()
tk.Label(root, text="ยังไม่ได้คลิก").pack()
btn = tk.Button(root, text="คลิกที่นี่")
btn.pack()
root.mainloop()

# %%
def change_txt():
    lb.config(text="คลิกแล้ว")
    lb.pack()

# %%
## ระดับ 2
root = tk.Tk()
lb = tk.Label(root, text="ยังไม่ได้คลิก")
lb.pack()
btn = tk.Button(root, text="คลิกที่นี่", command=change_txt)
btn.pack()
root.mainloop()

# %%
def change_txt():
    lb.config(text="คลิกแล้ว")
    lb.pack()
    lb.config(fg="red")
    lb.pack()

# %%
## ระดับ 3
root = tk.Tk()
tk.Button(root, text="คลิกที่นี่", command=change_txt).pack()
lb =tk.Label(root, text="ยังไม่ได้คลิก")
lb.pack()
root.geometry("200x150")
root.mainloop()
