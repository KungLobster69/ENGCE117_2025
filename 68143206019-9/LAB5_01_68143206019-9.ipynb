# %%
class  Robot :
    pass

# %%
r1 = Robot()
r2 = Robot()
print(r1)

# %%
r1.Name = "Commander"
r1.Battery = "100%"
r2.Name = "Commander"
r2.Battery = "100%"

# %%
print(r1.Battery)
# Out:
# 100%
# 2771519372800

# %%
print(f"is r1 the same as r2? {r1 == r2} Address r1 : {id(r1)} Address r2 : {id(r2)}")
# Out:
# is r1 the same as r2? False Address r1 : 2771519372800 Address r2 : 2771519026064

# %%
print(r1 == r2)
# Out:
# False
