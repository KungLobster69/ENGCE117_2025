# %%
class Circle :
    def draw(self) :
        print("🔴 วาดวงกลม")
class Square :
    def draw(self) :
        print("🟦 วาดสี่เหลี่ยม")

# %%
s = Square()
c = Circle()

# %%
c.draw()
s.draw()
# Out:
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
List = [c,s,c,s]

for i in List :
    i.draw()
# Out:
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
def render_screen(shape_list) :
    for i in shape_list :
        i.draw()

# %%
class triangle :
    def draw(self) :
        print("🔺 วาดสามเหลี่ยม")

# %%
t = triangle()
shape = [c,t,s]

# %%
render_screen(shape)
# Out:
# 🔴 วาดวงกลม
# 🔺 วาดสามเหลี่ยม
# 🟦 วาดสี่เหลี่ยม
