# %%
class Spy :
    def __init__(self):
        self.username = "James Bond"
        self._agency = "MI6"
        self.__code = "007"
        pass

# %%
Bond = Spy()

# %%
print(Bond.username)
print(Bond._agency)
print(Bond._Spy__code)

# %%
print(Bond.__code)
