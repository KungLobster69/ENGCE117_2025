# %%
import os

# %%
cwd = os.getcwd()
print(cwd)
Target = os.path.join(cwd)
# Out:
# c:\Users\Admin\OneDrive\Desktop\ENGCE117

# %%
try:
    with open('note.txt','x') as f:
        f.write("Nickname : Poori")
except FileExistsError:
    print("file Exists")

# %%
food = input("อาหารที่ชอบ")
with open('note.txt','a',encoding='utf-8') as f:
    f.write(f"\n{food}")

# %%
with open('note.txt','r') as f:
    txt = f.read()
print(txt)
# Out:
# Nickname : Poori/nkaià¹„à¸‚à¹ˆ
# (food)
# à¹„à¸‚à¹ˆ
