# %%
class RobotPart:
    count = 0
    def __init__(self,Part = "Motor",category = "Mechanical"):
        self.Part = Part
        self.Type = category
        RobotPart.count += 1

# %%
p1 = RobotPart()
p2 = RobotPart()

# %%
print(f"Part:{p1.Part},Type{p1.Type}")
print(f"Total parts in system : {RobotPart.count}")
# Out:
# Part:Motor,TypeMechanical
# Total parts in system : 2

# %%
print(f"p1.count = RobotPart.count? {p1.count == RobotPart.count} (เพราะทั้งทั้งคู่ชี้ไปที่ตัวแปรเดียวกันในระดับคลาส)")
# Out:
# p1.count = RobotPart.count? True (เพราะทั้งทั้งคู่ชี้ไปที่ตัวแปรเดียวกันในระดับคลาส)
