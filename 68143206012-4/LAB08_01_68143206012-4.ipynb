# %%
class Circle:
    def draw(shape):
        print("🔴วาดวงกลม")

class Square:
    def draw(shape):
        print("🟦วาดสี่เหลี่ยม")

d1 = Circle()
d2 = Square()

d1.draw()
d2.draw()
# Out:
# 🔴วาดวงกลม
# 🟦วาดสี่เหลี่ยม

# %%
list = [Circle(), Square(), Circle(), Square()]

print("--- เริ่มการวาดแบบ Loop ---")
for item in list:
    item.draw()
# Out:
# --- เริ่มการวาดแบบ Loop ---
# 🔴วาดวงกลม
# 🟦วาดสี่เหลี่ยม
# 🔴วาดวงกลม
# 🟦วาดสี่เหลี่ยม

# %%
def render_screen(shape_list):
    print(f"--- Rendering {len(shape_list)} shapes ---")
    for item in shape_list:
        item.draw()
    
class Triangle():
    def draw(shape):
        print("🔺วาดสามเหลี่ยม")

render_screen([Circle(), Triangle(), Square()])
# Out:
# --- Rendering 3 shapes ---
# 🔴วาดวงกลม
# 🔺วาดสามเหลี่ยม
# 🟦วาดสี่เหลี่ยม
