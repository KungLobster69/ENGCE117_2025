# %%
class WiFi:
    def connect(device):
        print("📡 Connected to WiFi network")
        
class Bluetooth:
    def connect(device):
        print("🔵 Connected to Bluetooth device") 
        
d1 = WiFi()
d2 = Bluetooth()

d1.connect()
d2.connect()
# Out:
# 📡 Connected to WiFi network
# 🔵 Connected to Bluetooth device

# %%
def initialize_system(device):
    print("System initializing...")
    device.connect()
    
initialize_system(d1)
initialize_system(d2)
# Out:
# System initializing...
# 📡 Connected to WiFi network
# System initializing...
# 🔵 Connected to Bluetooth device

# %%
def initialize_safe(device):
    try:
        print("System initializing...")
        device.connect()
    except:
        raise AttributeError(f"❌ Error: '{device}' เชื่อมต่อไม่ได้ ไม่มีฟังก์ชันconnect")
        
fake = 'สายแลนปลอม'

initialize_safe(d1)
initialize_safe(d2)
initialize_safe(fake)
# Out:
# System initializing...
# 📡 Connected to WiFi network
# System initializing...
# 🔵 Connected to Bluetooth device
# System initializing...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4, in initialize_safe(device)
#       3     print("System initializing...")
# ----> 4     device.connect()
#       5 except:
#
# AttributeError: 'str' object has no attribute 'connect'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 12
#      10 initialize_safe(d1)
#      11 initialize_safe(d2)
# ---> 12 initialize_safe(fake)
#
# Cell In[3], line 6, in initialize_safe(device)
#       4     device.connect()
#       5 except:
# ----> 6     raise AttributeError(f"❌ Error: '{device}' เชื่อมต่อไม่ได้ ไม่มีฟังก์ชันconnect")
#
# AttributeError: ❌ Error: 'สายแลนปลอม' เชื่อมต่อไม่ได้ ไม่มีฟังก์ชันconnect
