# %%
from abc import ABC, abstractmethod


class IoTDevice(ABC):
    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass

class SmartLight(IoTDevice):
    def turn_on(self):
        print("💡 ไฟเปิด")

    def turn_off(self):
        print("🌑 ไฟปิด")
        
        
light1 = SmartLight()

light1.turn_on()
light1.turn_off()
# Out:
# 💡 ไฟเปิด
# 🌑 ไฟปิด

# %%
class SmartSpeaker(IoTDevice):
    def turn_on(self):
        print("🔊 ลำโพงเปิด")
    # ไม่มีฟังก์ชั่น turn_off
        
try:
    speaker1 = SmartSpeaker()
except: 
    raise #TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 7
#       3         print("🔊 ลำโพงเปิด")
#       6 try:
# ----> 7     speaker1 = SmartSpeaker()
#       8 except:
#       9     raise #TypeError
#
# TypeError: Can't instantiate abstract class SmartSpeaker without an implementation for abstract method 'turn_off'

# %%
def test_device(device):
    if isinstance(device, IoTDevice):
        print("Testing SmartLight...") 
        device.turn_on()
        device.turn_off()
    else:
        print("⚠ไม่ใช่อุปกรณ์ IoT ทีรองรับ")


test_device(SmartLight())
test_device("RGBLight")
# Out:
# Testing SmartLight...
# 💡 ไฟเปิด
# 🌑 ไฟปิด
# ⚠ไม่ใช่อุปกรณ์ IoT ทีรองรับ
