# %%
class spy:
    def __init__(self):
        self.name = "James Bond"
        self._agency = "MI6"
        self.__code = "007"
        
bond = spy()

print(bond.name)
print(bond._agency)
try:
    print(bond.__code)
except:
    print("Error!")

print(bond._spy__code)
# Out:
# James Bond
# MI6
# Error!
# 007
