# %%
scores = [80, 55, 90, 75, 60]
print("Output: ", scores[:2], scores[-1:])
# Out:
# Output:  [80, 55] [60]

# %%
ids = [101, 102, 103, 104, 105, 106]
ids = ids[::-1]
print("Output: ", ids[::2])
# Out:
# Output:  [106, 104, 102]

# %%
data = [10, 20, 99, 99, 99, 60, 70]
data[2:5] = [0]
print("Output: ", data)
# Out:
# Output:  [10, 20, 0, 60, 70]
