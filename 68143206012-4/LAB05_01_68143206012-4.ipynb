# %%
class robot:

    pass

r1 = robot()

print(r1)

# %%
r1.name = "Commander"
r1.battery = 100

print(f"Robot Name: {r1.name}, Battery: {r1.battery}%")
# Out:
# Robot Name: Commander, Battery: 100%

# %%
r2 = robot()
r2.name = "Commander"
r2.battery = 100

print("Is r1 the same as r2?")
print(f"{r1 is r2} Address r1: {r1} Address r2: {r2}")
# Out:
# Is r1 the same as r2?
# False Address r1: <__main__.robot object at 0x000001B6269E94D0> Address r2: <__main__.robot object at 0x000001B6287C5A50>
