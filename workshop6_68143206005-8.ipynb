# %%
from collections import Counter
text = "apple banana apple orange banana apple"
wor = text.split()
counter = Counter(words)
most_common_wor = counter.most_common(1)
print(most_common_wor)
# Out:
# [('apple', 3)]

# %%
names = ["Alice","Bob","Charlie","David","Eve"]
from collections import defaultdict
names = ["Alice", "Bob", "Charlie", "David", "Eve"]
gro = defaultdict(list)
for name in names:
    gro[len(name)].append(name)
print(dict(gro))
# Out:
# {5: ['Alice', 'David'], 3: ['Bob', 'Eve'], 7: ['Charlie']}

# %%
from collections import deque
logs = deque(maxlen=3)
logs.append("Log1")
logs.append("Log2")
logs.append("Log3")
logs.append("Log4")
logs.append("Log5")
print(list(logs))
# Out:
# ['Log3', 'Log4', 'Log5']
