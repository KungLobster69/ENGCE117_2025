# %%
class Spy:
    def __init__(self):
        self.name = "James Bond"
        self._agency = "MI6"
        self.__code = "007"
bond = Spy()
print(bond.name)
print(bond._agency)
print(bond._Spy__code)
# Out:
# James Bond
# MI6
# 007
