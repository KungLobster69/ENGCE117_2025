# %%
raw_names = ["  somchai  ", " alice ", "  BOB ", " c "]
cleaned_names = list(map(lambda name: name.strip().lower(), raw_names))
print(cleaned_names)
# Out:
# ['somchai', 'alice', 'bob', 'c']

# %%
cleaned_names = ['somchai', 'alice', 'bob', 'c']
filtered_names = list(filter(lambda name: len(name) > 2, cleaned_names))
print(filtered_names)
# Out:
# ['somchai', 'alice', 'bob']

# %%
raw_names = [" somchai ", "alice", " BOB", "c"]; final_result = [name.strip().lower() for name in raw_names if len(name.strip()) > 2]; print(final_result)
# Out:
# ['somchai', 'alice', 'bob']
