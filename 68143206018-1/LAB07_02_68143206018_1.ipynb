# %%
#Level 1
class Character:
    def __init__(self, name, hp, power):
        self.name = name
        self.hp = hp
        self.power = power
    def take_damage(self, amount):
        self.hp -= amount
        print(f"{self.name} took {amount} dmg. (HP left: {self.hp})")
    def is_alive(self):
        return self.hp > 0
    def attack(self, target):
        print(f"{self.name} attacks {target.name}!")
        target.take_damage(self.power)

# %%
#Level 2
class Warrior(Character):
    def __init__(self, name, hp, power, defense):
        super().__init__(name, hp, power)
        self.defense = defense
    def take_damage(self, amount):
        damage = max(amount - self.defense, 0)
        super().take_damage(damage)

# %%
#Level 3
class Mage(Character):
    def __init__(self, name, hp, power, mana):
        super().__init__(name, hp, power)
        self.mana = mana
    def attack(self, target):
        if self.mana >= 10:
            print(f"{self.name} casts Fireball")
            damage = self.power + 15
            self.mana -= 10
        else:
            print(f"{self.name} attacks normally")
            damage = self.power
        target.take_damage(damage)

# %%
# Level 3 : Battle Simulation

warrior = Warrior("Arthur", 100, 15, 5)
mage = Mage("Loki", 80, 10, 50)
print("--- BATTLE START ---")
while warrior.is_alive() and mage.is_alive():
    warrior.attack(mage)
    if mage.is_alive():
        mage.attack(warrior)
print("\n🏆 Winner:", warrior.name if warrior.is_alive() else mage.name)
# Out:
# --- BATTLE START ---
# Arthur attacks Loki!
# Loki took 15 dmg. (HP left: 65)
# Loki casts Fireball
# Arthur took 20 dmg. (HP left: 80)
# Arthur attacks Loki!
# Loki took 15 dmg. (HP left: 50)
# Loki casts Fireball
# Arthur took 20 dmg. (HP left: 60)
# Arthur attacks Loki!
# Loki took 15 dmg. (HP left: 35)
# Loki casts Fireball
# Arthur took 20 dmg. (HP left: 40)
# Arthur attacks Loki!
# Loki took 15 dmg. (HP left: 20)
# Loki casts Fireball
# Arthur took 20 dmg. (HP left: 20)
# Arthur attacks Loki!
# Loki took 15 dmg. (HP left: 5)
# Loki casts Fireball
# Arthur took 20 dmg. (HP left: 0)
#
# 🏆 Winner: Loki
