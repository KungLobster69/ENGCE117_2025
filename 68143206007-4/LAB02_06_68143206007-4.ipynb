# %%
from collections import Counter
text = "apple banana apple orange banana apple"
words = text.split() 
word_counts = Counter(words)
most_common = word_counts.most_common(1)
print(f"Word Counts: {word_counts}")
print(f"Most Common: {most_common}")
# Out:
# Word Counts: Counter({'apple': 3, 'banana': 2, 'orange': 1})
# Most Common: [('apple', 3)]

# %%
from collections import defaultdict
names = ["Alice", "Bob", "Charlie", "David", "Eve"]
groups_by_length = defaultdict(list)
for name in names:
    length = len(name)
    groups_by_length[length].append(name)
print(dict(groups_by_length))
# Out:
# {5: ['Alice', 'David'], 3: ['Bob', 'Eve'], 7: ['Charlie']}

# %%
from collections import deque
logs_to_add = ["Log1", "Log2", "Log3", "Log4", "Log5"]
recent_logs = deque(maxlen=3)
for log in logs_to_add:
    print(f"Adding {log}...")
    recent_logs.append(log)
print(f"\nFinal Logs (3 ล่าสุด): {list(recent_logs)}")
# Out:
# Adding Log1...
# Adding Log2...
# Adding Log3...
# Adding Log4...
# Adding Log5...
#
# Final Logs (3 ล่าสุด): ['Log3', 'Log4', 'Log5']
