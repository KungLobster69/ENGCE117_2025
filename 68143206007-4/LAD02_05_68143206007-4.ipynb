# %%
names = ["alice", "bob", "charlie"]
Up_name = [name.upper() for name in names]
print (f" Upper: {Up_name}")
# Out:
#  Upper: ['ALICE', 'BOB', 'CHARLIE']

# %%
prices = [100, 250, 80, 500, 120]
price2 = [x + (x*0.07)  for x in prices if x > 200 ]
print (f"VAT Prices: price2)
# Out:
# [267.5, 535.0]
