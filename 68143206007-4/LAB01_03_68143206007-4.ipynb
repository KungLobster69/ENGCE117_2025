# %%
inventory = {'apple': 10, 'banana': 20}
def check_price (item_name):
    item_name = inventory.get(item_name, 0)
    return item_name
item_name = check_price('Durian')
print(f"Check: {item_name}")
# Out:
# Check: 0

# %%
inventory = {'apple': 10, 'banana': 20}

def add_stock(item, quantity):
    inventory[item] = inventory.get(item, 0) + quantity

add_stock('apple', )
add_stock('orange', 7)

print(inventory)
# Out:
# {'apple': 60, 'banana': 20, 'orange': 7}
