# %%
student = ("Somchai","Engineering", 3.75)
name,  Dept, gpa= student
print(f"Name:{name}, Dept: {Dept}, GPA: {gpa}")
# Out:
# Name:Somchai, Dept: Engineering, GPA: 3.75

# %%
numbers = input((list()))
def  get_stats() :
    min_val = min(numbers)
    max_val = max(numbers)
    return min_val, max_val
resolution =  get_stats()
print(f"Min:{resolution[0]}, Max: {resolution[1]}")
# Out:
# Min:1, Max: 8

# %%
scores = [10, 20, 30, 40, 50, 60]
low, *others, high = scores
print(f"Low: {low}, High: {high}, Others: {others}")
# Out:
# Low: 10, High: 60, Others: [20, 30, 40, 50]
