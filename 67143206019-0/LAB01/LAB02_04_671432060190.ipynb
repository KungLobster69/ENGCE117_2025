# %%
visitors = ['user1', 'user2', 'user1', 'user3', 'user2']
unique_visitors = set(visitors)
unique_count = len (unique_visitors)
print(f"# Output: Unique Count: {unique_count}")
# Out:
# # Output: Unique Count: 3

# %%
group_A = {'Reading', 'Coding', 'Gaming'}
group_B = {'Coding', 'Traveling', 'Gaming'}
common_interests = group_A & group_B

print(f"# Output: Common: {common_interests}")
# Out:
# # Output: Common: {'Coding', 'Gaming'}

# %%
group_A = {'Reading', 'Coding', 'Gaming'}
group_B = {'Coding', 'Traveling', 'Gaming'}
only_A = group_A - group_B
print(f"# Output: Only A: {only_A}\n")
print(f"# Output: Diff: {symmetric_diff}")
# Out:
# # Output: Only A: {'Reading'}
#
# # Output: Diff: {'Reading', 'Traveling'}
