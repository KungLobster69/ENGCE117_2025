# %%
raw_names = [" somchai ","alice"," BOB","C"]
res_map = list(map(lambda name: name.strip().lower(), raw_names))
print(res_map)
# Out:
# ['somchai', 'alice', 'bob', 'c']

# %%
raw_names = [" somchai ","alice"," BOB","C"]
cleaned_names = list(map(lambda name: name.strip().lower(),raw_names))
f = list(filter(lambda name: len(name) >2, cleaned_names))
print(f)
# Out:
# ['somchai', 'alice', 'bob']

# %%
one_liner_output = [name.strip().lower() for name in raw_names if len(name.strip()) > 2]
print(f" {one_liner_output}")
# Out:
#  ['somchai', 'alice', 'bob']
