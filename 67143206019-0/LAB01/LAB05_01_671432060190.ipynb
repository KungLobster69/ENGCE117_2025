# %%
class Robot:
    pass  


r1 = Robot()
r2 = Robot()

print(r1)

# %%
class Robot:
    pass

r1 = Robot()

r1.name = "Commander"
r1.batterry = 100
print(f"Robot name: {r1.name}, Battery: {r1.batterry}%")
# Out:
# Robot name: Commander, Battery: 100%

# %%
class Robot:
    pass


r1 = Robot()
r1.name = "Commander"
r1.battery = 100


r2 = Robot()
r2.name = "Commander"
r2.battery = 100


is_same = r1 is r2

print(f" {is_same}")
print(f"Address r1: {id(r1)}")
print(f"Address r2: {id(r2)}")
# Out:
#  False
# Address r1: 2064350222704
# Address r2: 2064350218048
