# %%
class Circle:
    def draw(self):
        print("🔴 วาดวงกลม")
class Square:
    def draw(self):
        print(" 🟦 วาดรูปสี่เหลี่ยม")

my_circle = Circle()
my_square = Square() 

my_circle.draw()
my_square.draw()
# Out:
# 🔴 วาดวงกลม
#  🟦 วาดรูปสี่เหลี่ยม

# %%
class Circle:
    def draw(self):
        print("🔴 วาดวงกลม")
class Square:
    def draw(self):
        print(" 🟦 วาดรูปสี่เหลี่ยม")

shaper =  [Circle(), Square(), Circle(), Square()]

print("--- เริ่มการวาดแบบ Loop ---")
for item in shaper:
    item.draw()
# Out:
# --- เริ่มการวาดแบบ Loop ---
# 🔴 วาดวงกลม
#  🟦 วาดรูปสี่เหลี่ยม
# 🔴 วาดวงกลม
#  🟦 วาดรูปสี่เหลี่ยม

# %%
class Circle:
    def draw(self):
        print("🔴 วาดวงกลม")
class Square:
    def draw(self):
        print("🟦 วาดรูปสี่เหลี่ยม")
class Triangle:
    def draw(self):
        print("🔺 วาดสามเหลี่ยม")

def render_screen(shape_list):
    print(" --- Rendering 3 shapes ---  ")
    
    for shape in shape_list:
        shape.draw()
        
shape = [Circle(), Triangle(), Square()]

render_screen(shape)
# Out:
#  --- Rendering 3 shapes ---
# 🔴 วาดวงกลม
# 🔺 วาดสามเหลี่ยม
# 🟦 วาดรูปสี่เหลี่ยม
