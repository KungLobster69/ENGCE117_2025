# %%
class WiFi:
    def connect(self):
        print("📡 Connected To WiFi network")
class Bluetooth:
    def connect(self):
        print("🔵 Paired with Bluetooth device")
   
w = WiFi()
b = Bluetooth()

w.connect()
b.connect()
# Out:
# 📡 Connected To WiFi network
# 🔵 Paired with Bluetooth device

# %%
class WiFi:
    def connect(self):
        print("📡 Connected To WiFi network")
class Bluetooth:
    def connect(self):
        print("🔵 Paired with Bluetooth device")
        
def initialize_system(device):
    print("System initializing...")
    
    device.connect()

w_= WiFi()
b = Bluetooth()

initialize_system(w)
initialize_system(b)
# Out:
# System initializing...
# 📡 Connected To WiFi..
# System initializing...
# 🔵 Paired with Bluetooth device

# %%
def initialize_safe(device):
    try :
       
        device.connect()
    except AttributeError:
        
        print(f"❌ Error: Object '{device}' ไม่มีฟังก์ชัน connect")

print("Testing with a String:")
initialize_safe("สายแลนปลอม")

print("Testing with an Integer:")
initialize_safe("12345")
# Out:
# Testing with a String:
# ❌ Error: Object 'สายแลนปลอม' ไม่มีฟังก์ชัน connect
# Testing with an Integer:
# ❌ Error: Object '12345' ไม่มีฟังก์ชัน connect
