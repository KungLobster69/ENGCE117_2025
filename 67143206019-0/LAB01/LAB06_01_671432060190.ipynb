# %%
class Spy:
    def __init__(self):
        
        self.name = "James Bond"          
        self._agency = "MI6"              
        self.__code = "007"             
bond = Spy()
print(bond.name)      
print(bond._agency)   
try:
    print(bond.__code)
except AttributeError:
    print("Error: พยายามเข้าถึงตัวแปร Private โดยตรงไม่ได้!")

print(bond._Spy__code)
# Out:
# James Bond
# MI6
# Error: พยายามเข้าถึงตัวแปร Private โดยตรงไม่ได้!
# 007
