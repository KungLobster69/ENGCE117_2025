# %%
class RobotPart:
   
    category = "Mechanical"

    def __init__(self, name):
        
        self.name = name


p1 = RobotPart("Motor")


print(f"Part: {p1.name}, Type: {RobotPart.category}")
# Out:
# Part: Motor, Type: Mechanical

# %%
class RobotPart:
    total_count = 0
    category = "Mechaical"
    
    def __init__(self, name):
        self.name = name  
        RobotPart.total_count += 1 


p1 = RobotPart("Motor")
p2 = RobotPart("Gear")


print(f"Total parts in system: {RobotPart.total_count}")
# Out:
# Total parts in system: 2

# %%
class RobotPart:
    total_count = 0
    cattegory = "Mechaical"
    
    def  __init__(self,name):
        self.name = name
        RobotPart.total_count += 1

p1 = RobotPart("Moter")
p2 = RobotPart("Gear")
p3 = RobotPart("Sensor")

is_shared = p1.total_count is RobotPart.total_count


print(f"Is it shared? {is_shared}")
print(f"Value via p1: {p1.total_count}")
print(f"Value via Class: {RobotPart.total_count}")
# Out:
# Is it shared? True
# Value via p1: 3
# Value via Class: 3
