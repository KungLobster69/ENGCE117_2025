# %%
import tkinter as tk


root = tk.Tk()


root.title("WorkShop")


root.geometry("")


root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()
root.title("Workshop")
root.geometry("")


label = tk.Label(root, text="Hello GUI", font=("Arial", 16))


label.pack(pady=50) 


root.mainloop()

# %%
import tkinter as tk


root = tk.Tk()


root.title("My First App")
root.geometry("400x300")


label = tk.Label(root, text="Hello GUI", font=("Arial", 18))
label.pack(pady=50) 


root.mainloop()
