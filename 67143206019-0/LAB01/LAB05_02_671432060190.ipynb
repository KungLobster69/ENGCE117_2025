# %%
class Robot:
   
   def  __init__(self,name,model):
        self.name = name
        self.model = model
r1 = Robot("R-01", "Explorer")

print(f"Robor: {r1.name} ({r1.model})")
# Out:
# Robor: R-01 (Explorer)

# %%
class Robot:
    
    def __init__(self, name, model, battery=100):
        self.name = name
        self.model = model
        self.battery = battery
        
r2 = Robot("R-02", "Explorer")

print(f"{r2.name} Battery: {r2.battery}%")
# Out:
# R-02 Battery: 100%

# %%
class Robot:
    def __init__(self, name, model, battery=100):
        self.name = name
        self.model = model
        self.battery = battery
        
        
        if self.battery < 20:
            print(f"Warning: {self.name} has Low Battery!")


r3 = Robot("R-03", "Explorer", 15)
# Out:
# Warning: R-03 has Low Battery!
