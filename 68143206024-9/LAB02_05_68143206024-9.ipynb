# %%
# Workshop 5 - The Refactorer
# Level 1 (Easy): Basic Transformation

names = ["alice", "bob", "charlie"]
upper_names = [n.upper() for n in names]
print(f"Upper: {upper_names}")
# Out:
# Upper: ['ALICE', 'BOB', 'CHARLIE']

# %%
# Level 2 (Medium): Filtering & Mapping

prices = [100,250,80,500,120]
vat_prices = [price * 1.07 for price in prices if price > 200] # เอาไปคูณ * 1.07 
print("VAT Prices:", vat_prices)
# Out:
# VAT Prices: [267.5, 535.0]

# %%
# Level 3 (Hard): Dictionary Inversion

currencies = {'USD': 35, 'EUR': 38, 'JPY': 0.25}
inverted_currencies = {value: key for key, value in currencies.items() if value > 1}
print(f"Inverted: {inverted_currencies}")
# Out:
# Inverted: {35: 'USD', 38: 'EUR'}
