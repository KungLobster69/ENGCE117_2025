# %%
class Circle:
     def draw(self):

         print("🔴 วาดวงกลม")



class Square:
    def draw(self):

        print("🟦 วาดสี่หลี่ยม")

O = Circle()
K = Square()

O.draw()
K.draw()
# Out:
# 🔴 วาดวงกลม
# 🟦 วาดสี่หลี่ยม

# %%
class Shape:
    def draw(self):
        pass

class Circle(Shape):
    def draw(self):
        print("🔴 วาดวงกลม")


class Square(Shape):
    def draw(self):
        print("🟦 วาดสี่เหลี่ยม")


shapes = [Circle(), Square(), Circle(), Square()]

print("--- เริ่มการวาดแบบ Loop ---")
for item in shapes:
    item.draw()
# Out:
# --- เริ่มการวาดแบบ Loop ---
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม
# 🔴 วาดวงกลม
# 🟦 วาดสี่เหลี่ยม

# %%
class Circle:
     def draw(self):

         print("🔴 วาดวงกลม")

class Triangle:
    def draw(self):

        print("🔺 วาดสามเหลี่ยม")

class Square:
    def draw(self):

        print("🟦 วาดสี่หลี่ยม")


def render_screen(shape_list):
    print(f"--- Rendering 3 shapes ---")
    for shape in shape_list:
        shape.draw()


shapes = [Circle(), Triangle(), Square()]
render_screen(shapes)
# Out:
# --- Rendering 3 shapes ---
# 🔴 วาดวงกลม
# 🔺 วาดสามเหลี่ยม
# 🟦 วาดสี่หลี่ยม
