# %%
scores = [80, 55, 90, 75, 60]
Step = scores [0:2]
last_one = scores[-1:]
print(scores[0:2],scores[-1:])
# Out:
# [80, 55] [60]

# %%
ids = [101, 102, 103, 104, 105, 106]
Reversal = ids
Step = ids
print(ids[::-2])
# Out:
# [106, 104, 102]

# %%
data = [10, 20, 99, 99, 99, 60, 70]
Batch_Update = data
data[2:5] = [0]
print(data)
# Out:
# [10, 20, 0, 60, 70]
