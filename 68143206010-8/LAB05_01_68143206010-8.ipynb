# %%
class Robot:
    pass

r1 = Robot()

print(r1)
# Out:
# <__main__.Robot object at 0x000002528C020830>

# %%
class Robot:
    pass

r1.name = "Commander"
r1.battery = 100

print(f"Robot {r1.name}: Commander, {r1.battery}%:")
# Out:
# Robot Commander: Commander, 100%:

# %%
class Robot:
    def __init__(self, name, power):
        self.name = name
        self.power = power

r1 = Robot("Robo-1", 100)
r2 = Robot("Robo-1", 100)

print("Is r1 the same as r2?", r1 is r2)
print("Address r1:", id(r1))
print("Address r2:", id(r2))
# Out:
# Is r1 the same as r2? False
# Address r1: 2553559520928
# Address r2: 2553565384208
