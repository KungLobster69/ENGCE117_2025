# %%
inventory = {'apple': 10,'banana': 20} 

def check_price(item_name):
    price = inventory.get(item_name, 0)    
    return f"Check {item_name}: {price}"

print(check_price("Durian"))
# Out:
# Check Durian: 0

# %%
inventory = {'apple': 10,'banana': 20}

def add_stock(item, quantity):
    inventory[item] = inventory.get(item, 0) + quantity
add_stock("apple", 5)
print(inventory)
# Out:
# {'apple': 15, 'banana': 20}

# %%
branch = {'banana': 5,'orange': 10}
inventory = {'apple': 15, 'banana': 20}
branch2 = {'banana': 5, 'orange': 10}

for item, qty in branch2.items():
    inventory[item] = inventory.get(item, 0) + qty

print(inventory)
# Out:
# {'apple': 15, 'banana': 25, 'orange': 10}
