# %%
class Robot:

    pass
r1 = Robot()
print(r1)

# %%
class Robot:

    pass
r1 = Robot()

r1.name =  "commander"
r1.battery = 100

print(r1.name)
print(r1.battery)
# Out:
# commander
# 100

# %%
class Robot:

    pass
r1 = Robot()

r1.name =  "commander"
r1.battery = 100

r2 = Robot()
r2. name = "commander"
r2.battert = 100

print(r1 is r2)
print(id(r1))
print(id(r2))
# Out:
# False
# 2608370809552
# 2608370807824
