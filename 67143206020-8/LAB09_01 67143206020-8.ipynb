# %%
class RPGCharacter:
    def __init__(self, name, hp, mp):
        self.name = name
        self.hp = hp
        self.mp = mp

    def __str__(self):
        return f"{self.name} (HP: {self.hp}, MP: {self.mp})"

hero = RPGCharacter ("hero",100,50)
print(hero)
# Out:
# hero (HP: 100, MP: 50)

# %%
class RPGCharacter:
    def __init__(self, name, hp, mp):
        self.name = name
        self.hp = hp
        self.mp = mp

    def __str__(self):
        return f"{self.name} (HP: {self.hp}, MP: {self.mp})"

    def __add__(self, other):
        if not isinstance(other, RPGCharacter):
            return NotImplemented
        
        new_name = self.name + other.name
        new_hp = self.hp + other.hp
        new_mp = self.mp + other.mp
        
        return RPGCharacter(new_name, new_hp, new_mp)



char1 = RPGCharacter("Hero", 100, 50)
char2 = RPGCharacter("Mage", 60, 120)

fusion = char1 + char2
print(fusion)
# Out:
# HeroMage (HP: 160, MP: 170)

# %%
class RPGCharacter:
    def __init__(self, name, hp, mp):
        self.name = name
        self.hp = hp
        self.mp = mp

    def __str__(self):
        return f"{self.name} (HP: {self.hp}, MP: {self.mp})"

    def __add__(self, other):
        if isinstance(other, RPGCharacter):
            new_name = self.name + other.name
            new_hp = self.hp + other.hp
            new_mp = self.mp + other.mp
            return RPGCharacter(new_name, new_hp, new_mp)

        elif isinstance(other, int):
            return RPGCharacter(self.name, self.hp + other, self.mp)

        else:
            return NotImplemented


char1 = RPGCharacter("Hero", 100, 50)
char2 = RPGCharacter("Mage", 60, 120)

fusion = char1 + char2
print(fusion)

heal = char1 + 50
print(heal)
# Out:
# HeroMage (HP: 160, MP: 170)
# Hero (HP: 150, MP: 50)
