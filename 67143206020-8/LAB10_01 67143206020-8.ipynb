# %%
import tkinter as tk

root = tk.Tk()

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()

label = tk.Label(root, text="Hello GUI")



label.pack()

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()


root.title("My First App")


root.geometry("400x300")


label = tk.Label(root, text="Hello GUI")
label.pack()

root.mainloop()
