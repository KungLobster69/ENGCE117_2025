# %%
import tkinter as tk

root = tk.Tk()
root.title("Numpad")
root.geometry("250x300")

display = tk.Entry(root, font=("Arial", 18), justify="right")
display.grid(row=0, column=0, columnspan=3, padx=5, pady=5, sticky="nsew")

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()
root.title("Numpad")
root.geometry("250x300")

display = tk.Entry(root, font=("Arial", 18), justify="right")
display.grid(row=0, column=0, columnspan=3, padx=5, pady=5, sticky="nsew")


numbers =1
for row in range(1,4):
   for col in range(3):
      btn = tk.Button(root, text=str(numbers), width=5, height=2)
      btn.grid(row=row, column=col, padx=5, pady=5)
      numbers += 1
root.mainloop()

# %%
import tkinter as tk


root = tk.Tk()
root.title("Numpad")
root.geometry("250x300")


def click_number(num):
    current = entry.get()
    entry.delete(0, tk.END)
    entry.insert(0, current + str(num))


entry = tk.Entry(root, font=("Arial", 18), justify="right")
entry.grid(row=0, column=0, columnspan=3, padx=10, pady=10, sticky="nsew")


numbers = 1
for row in range(1, 4):
    for col in range(3):
        btn = tk.Button(root, text=str(numbers),
                        font=("Arial", 14),
                        command=lambda n=numbers: click_number(n))
        btn.grid(row=row, column=col, padx=5, pady=5, sticky="nsew")
        numbers += 1

btn_zero = tk.Button(root, text="0",
                     font=("Arial", 14),
                     command=lambda: click_number(0))
btn_zero.grid(row=4, column=0, columnspan=2,
              padx=5, pady=5, sticky="nsew")

btn_dot = tk.Button(root, text=".",
                    font=("Arial", 14),
                    command=lambda: click_number("."))
btn_dot.grid(row=4, column=2,
             padx=5, pady=5, sticky="nsew")


for i in range(5):
    root.grid_rowconfigure(i, weight=1)

for i in range(3):
    root.grid_columnconfigure(i, weight=1)

root.mainloop()
