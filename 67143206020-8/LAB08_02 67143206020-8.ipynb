# %%
class Wifi:
   def connect(self):
      print("📡 Connected to WiFi...")

class Bluetooth:
   def connect(self):
      print("🔵 Paired with Bluetooth...")

wifi = Wifi()
bluetooth =  Bluetooth() 


wifi.connect()
bluetooth.connect()
# Out:
# 📡 Connected to WiFi...
# 🔵 Paired with Bluetooth...

# %%
class Wifi:
   def connect(self):
      print("📡 Connected to WiFi...")

class Bluetooth:
   def connect(self):
      print("🔵 Paired with Bluetooth...")


def initialize_system(device):
    print("System initializing...")
    device.connect()
     
   

wifi = Wifi()
bluetooth =  Bluetooth() 


initialize_system(wifi)
initialize_system(bluetooth)
# Out:
# System initializing...
# 📡 Connected to WiFi...
# System initializing...
# 🔵 Paired with Bluetooth...

# %%
class WiFi:
    def connect(self):
        print("📡 Connected to WiFi network")


class Bluetooth:
    def connect(self):
        print("🔵 Paired with Bluetooth device")


def initialize_safe(device):
    try:
        device.connect()
    except AttributeError:
        print(f" Error: Object '{device}' ไม่มีฟังก์ชัน connect")

initialize_safe("สายแลนปลอม")
initialize_safe(123)
# Out:
#  Error: Object 'สายแลนปลอม' ไม่มีฟังก์ชัน connect
#  Error: Object '123' ไม่มีฟังก์ชัน connect

# %%
class WiFi:
    def connect(self):
        print("📡 Connected to WiFi network")


class Bluetooth:
    def connect(self):
        print("🔵 Paired with Bluetooth device")


def initialize_safe(device):
    try:
        device.connect()
    except AttributeError:
        print(f" Error: Object '{device}' ไม่มีฟังก์ชัน connect")

wifi = WiFi()
bluetooth = Bluetooth()

initialize_safe(wifi)
initialize_safe(bluetooth)
# Out:
# 📡 Connected to WiFi network
# 🔵 Paired with Bluetooth device
