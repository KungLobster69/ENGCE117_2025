# %%
with open("note.txt", "w", encoding="utf-8") as f:
    f.write("Nickname: Foam")

food = input("อาหารที่ชอบ: ")

with open("note.txt", "a", encoding="utf-8") as f:
    f.write("\nอาหารที่ชอบ: " + food)

with open("note.txt", "r", encoding="utf-8") as f:
    data = f.read()
    print(data)
# Out:
# Nickname: Foam
# อาหารที่ชอบ: ลาบหมู
